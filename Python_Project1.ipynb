# %%
class thecozykettlecafe:
    def __init__(rp):

        print("\t\t\t\t the cozy kettle cafe")
        print("\t\t\t\t started-2025")
        print("\t\t\t\t near akshya patr")
        print("\n\n\t\t\t\t MENU")

        x=["Hot Coffee","iced beverages","mocktails","shakes"]
        for k in x:
            print("\n\n",k)
    def hotcoffee(rp):
        x=["espresso","americano","cappuccino","latte"]
        y=[150,160,100,100]
        indian_={"indian drinks":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n indian drinks \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position :"))
            c=int(input("enter the quantity:"))
            z=indian_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax=5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
    def icedbeverages(rp):
        x=["iced americano","iced latte","cold brew","iced mocha"]
        y=[120,150,70,80]
        indian_={"Indian drinks":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n Indian drinks \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position :"))
            c=int(input("enter the quantity:"))
            z=indian_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax=5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
    def mocktails(rp):
        x=["strawberry slush mocktail","virgin mojito","rose lemonade","choco mint cooler"]
        y=[150,100,110,130]
        indian_={"Indian drinks":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n Indian drinks \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position :"))
            c=int(input("enter the quantity:"))
            z=indian_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax=5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")
    def shakes(rp):
        x=["redvelevt strawberry shake","oreo shake","chocolate shake","vanilla shake"]
        y=[120,100,80,70]
        indian_={"Indian drinks":x,"price":y}
        import pandas as pd
        df=pd.DataFrame(indian_)
        print("\n\n Indian drinks \n\n")
        print(df)
        d=[]
        while x:
            x=True
            b=int(input("enter the value position :"))
            c=int(input("enter the quantity:"))
            z=indian_["price"][b]
            y=z*c
            d.append(y)
            x=input("you want to reorder(yes/no):")
            if(x=="no"):
                print("Thank you")
                break
        t=sum(d)
        m=(sum(d)*0.05)
        k=t+m
        from colorama import Fore,Back,Style
        print(Fore.BLACK+Back.RED+Style.BRIGHT+"servicetax=5%")
        print("Total Amount:",t,"Rupees")
        print("Total Amount Including Service Tax:",k,"Rupees")

# %%
obj=thecozykettlecafe()
# Out:
# 				 the cozy kettle cafe
# 				 started-2025
# 				 near akshya patr
#
#
# 				 MENU
#
#
#  Hot Coffee
#
#
#  iced beverages
#
#
#  mocktails
#
#
#  shakes

# %%
x=input("enter the type of food:")
if x=="hot coffee":
    print(obj.hotcoffee())
elif x=="iced beverages":
    print(obj.icedbeverages())
elif x=="mocktails":
    print(obj.mocktails())
elif x=="shakes":
    print(obj.shakes())
else:
    print("wrong option:\n please again choose the right option:")
# Out:
# enter the type of food: mocktails
#  Indian drinks
#
#
#                Indian drinks  price
# 0  strawberry slush mocktail    150
# 1              virgin mojito    100
# 2              rose lemonade    110
# 3          choco mint cooler    130
# enter the value position : 2
# enter the quantity: 2
# you want to reorder(yes/no): no
# Thank you
# servicetax=5%
# Total Amount: 220 Rupees
# Total Amount Including Service Tax: 231.0 Rupees
# None
